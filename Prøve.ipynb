# %%
import prøv
import numpy as np

# %%
l = 3
v_0_1 = np.arange(1000)
v_0 = np.tile(v_0_1,l)
prøv.asds(l,v_0)
# Out:
# array([595.68142754, 300.33821377, 593.69476795, ...,   0.76130181,
#          0.75622377,   0.74866595])

# %%
l = 11
v_0_1 = np.arange(1000)
v_0 = np.tile(v_0_1,l)
prøv.matrix(11,1000, prøv.asds(l,v_0))
# Out:
# c:[2.28061731e-05 2.29204431e-05 2.30362282e-05 ... 2.03279454e+00
#  2.07108326e+00 2.10962909e+00]
# u:[-4.38477774e+04 -4.36291740e+04 -4.34098843e+04 ... -4.91933632e-01
#  -4.82839112e-01 -4.74016976e-01]
# array([-7.88090539e+04, -7.86766723e+04, -7.81676699e+04, ...,
#        -4.91933632e-01, -4.82839112e-01, -4.74016976e-01])

# %%
prøv.loop(11,1000, v_0)
# Out:
# it:0
# c:[2.28061731e-05 2.29204431e-05 2.30362282e-05 ... 2.03279454e+00
#  2.07108326e+00 2.10962909e+00]
# u:[-4.38477774e+04 -4.36291740e+04 -4.34098843e+04 ... -4.91933632e-01
#  -4.82839112e-01 -4.74016976e-01]
# max:78809.05387799993
# it:1
# c:[7.47446216e-10 8.38306424e-10 8.22904911e-10 ... 5.82309565e+01
#  5.78054724e+01 5.91342535e+01]
# u:[-1.33788891e+09 -1.19288123e+09 -1.21520723e+09 ... -1.71729963e-02
#  -1.72994002e-02 -1.69106726e-02]
# max:4553324598.309735
# it:2
# C:\Users\cns486\Documents\GE_with_matrices\prøv.py:92: RuntimeWarning: divide by zero encountered in power
#   u = np.power(c,(1-sigma))/(1-sigma)
# c:[  0.           0.           0.         ... 125.94388659 127.30236774
#  128.66997109]
# u:[-1.00000000e+27 -1.00000000e+27 -1.00000000e+27 ... -7.94004399e-03
#  -7.85531344e-03 -7.77182113e-03]
# max:4.2436009272423216e+27
# it:3
# c:[  0.           0.           0.         ... 151.32798307 152.69418192
#  154.06955479]
# ...
