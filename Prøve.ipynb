# %%
import prøv
import numpy as np

# %%
prøv.asds(3)
# Out:
# 1 1
# array([300.33821377, 593.69476795, 589.73470022, ...,   0.75622377,
#          0.7511796 ,   0.74866595])

# %%
prøv.matrix(11,1000, prøv.asds(11))
# Out:
# 1 1
# [[0.85973044 0.         0.         ... 0.         0.         0.        ]
#  [0.         0.85973044 0.         ... 0.         0.         0.        ]
#  [0.         0.         0.85973044 ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 0.85973044 0.         0.        ]
#  [0.         0.         0.         ... 0.         0.85973044 0.        ]
#  [0.         0.         0.         ... 0.         0.         0.85973044]] 1.3894913391258015
# 0.5179505657517924 [1.20291890e-05 3.07844282e-06 3.11992511e-06 ... 2.01897391e+02
#  2.01922959e+02 2.01935893e+02]
# [1.20291890e-05 3.07844282e-06 3.11992511e-06 3.16196637e-06
#  3.20457415e-06 3.24775607e-06 3.29151987e-06 3.33587339e-06
#  3.38082458e-06 3.42638149e-06 3.47255229e-06 1.68226902e-03
#  1.68231644e-03 1.68236450e-03 1.68241321e-03 1.68246258e-03
#  1.68251261e-03 1.68256332e-03 1.68261471e-03 1.68266679e-03
#  1.68271957e-03 1.68277306e-03 3.37284975e-03 3.37290470e-03
# ...
