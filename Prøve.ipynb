# %%
import prøv
import numpy as np

# %%
l = 3
v_0_1 = np.arange(1000)
v_0 = np.tile(v_0_1,l)
prøv.asds(l,v_0)
# Out:
# array([595.68142754, 300.33821377, 593.69476795, ...,   0.76130181,
#          0.75622377,   0.74866595])

# %%
l = 11
v_0_1 = np.arange(1000)
v_0 = np.tile(v_0_1,l)
prøv.matrix(11,1000, prøv.asds(l,v_0))
# Out:
# c:[2.28061731e-05 2.29204431e-05 2.30362282e-05 ... 2.03279454e+00
#  2.07108326e+00 2.10962909e+00]
# u:[-4.38477774e+04 -4.36291740e+04 -4.34098843e+04 ... -4.91933632e-01
#  -4.82839112e-01 -4.74016976e-01]
# array([-7.87592034e+04, -7.84615082e+04, -7.81633911e+04, ...,
#        -1.19544787e+01, -1.19453842e+01, -1.19365620e+01])

# %%
prøv.loop(11,1000, v_0)
# Out:
# it:0
# c:[2.28061731e-05 2.29204431e-05 2.30362282e-05 ... 2.03279454e+00
#  2.07108326e+00 2.10962909e+00]
# u:[-4.38477774e+04 -4.36291740e+04 -4.34098843e+04 ... -4.91933632e-01
#  -4.82839112e-01 -4.74016976e-01]
# max:78759.20338261705
# it:1
# c:[4.69333628e-10 4.72959616e-10 4.76644668e-10 ... 7.50342495e+01
#  7.61293300e+01 7.72317640e+01]
# u:[-2.13068048e+09 -2.11434542e+09 -2.09799892e+09 ... -1.33272473e-02
#  -1.31355418e-02 -1.29480404e-02]
# max:2627869517.790049
# it:2
# C:\Users\cns486\Documents\GE_with_matrices\prøv.py:93: RuntimeWarning: divide by zero encountered in power
#   u = np.power(c,(1-sigma))/(1-sigma)
# c:[  0.           0.           0.         ... 131.36620411 132.66408426
#  133.9723582 ]
# u:[-1.00000000e+27 -1.00000000e+27 -1.00000000e+27 ... -7.61230795e-03
#  -7.53783517e-03 -7.46422630e-03]
# max:2.709041728768401e+27
# it:3
# c:[  0.           0.           0.         ... 152.0883574  153.42599003
#  154.77283774]
# ...
